# %% [markdown]
# ***
# <h1 style="background-color:lightgreen;font-family:newtimeroman;text-align:center;border-radius: 0px 50px">
#     <font color=black size=7>
#         Análise - Campeonato Brasileiro
#     </font>
# </h1>
#
# <p>Observação: Em desenvolvimento</p>
#
# ***

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Bases de Dados

# %%
path = "/Users/felipebarreto/Documents/Projeto - Campeonato Brasileiro/"

df = pd.read_csv(path + "campeonato-brasileiro-estatisticas-full.csv", sep=";")
times = pd.read_csv(path + "campeonato-brasileiro-full.csv", sep=";")
estados = pd.read_csv(path + "estados.csv", sep=';', encoding='latin-1') ; estados.columns = ['estado','uf','regiao']
temporadas = pd.read_csv(path + "temporadas.csv", sep =';')

# %%
for i in [df,times,estados,temporadas]:
    display(i.sample(3))
# Out:
#         ID  Mandante  Chutes  Chutes a gol Posse de bola  Passes  \
# 3327  7707         0     5.0           3.0           32%   344.0
# 2074  7074         1     7.0           3.0           47%   451.0
# 3561  7820         0    14.0           5.0           45%   394.0
#
#      Precisão de passe  Faltas  Cartões amarelos  Cartões vermelhos  \
# 3327               72%    16.0               2.0                0.0
# 2074               NaN    11.0               0.0                0.0
# 3561               75%    18.0               1.0                0.0
#
#       Impedimentos  Escanteios
# 3327           1.0         1.0
# 2074           2.0         7.0
# 3561           0.0         4.0
#         ID Rodada        Data Horário      Dia      Mandante  Visitante  \
# 3009  3010      2  2007-05-17   18h10   Sábado         Sport    Vitória
# 4826  4827     31  2011-10-23   16h00  Domingo  Athlético-PR      Ceará
# 3394  3395      2  2008-05-18   16h00  Domingo  Athlético-PR  São Paulo
#
# ...

# %%
## Algumas funções necessárias ##

# transformar string em datetime
def to_time(df, col):
    df[col] = pd.to_datetime(df[col])

# transformação de uma variável em um inteiro
def to_int (df, col):
    df[col] = df[col].str.astype(int)

def str_to_float (df, col):
    df[col] = df[col].str.replace('%', '').astype(float)

# plot dos valores faltantes
def missing_map(df, size_x=15, size_y=5, color = 'Reds'):
    plt.figure(figsize=(size_x,size_y))
    plt.title(f"Valores Faltantes em {df.name}", fontweight = 'bold', fontsize = 15)
    ax = sns.heatmap(df.isna().sum().to_frame(), annot = True, fmt = 'd', cmap = color)
    ax.set_ylabel("Variáveis", fontsize=12)
    ax.set_xlabel('Quantidade Faltante', fontsize=12)

# função para transformar as observações em minúsculas
def to_lower(df, col):
    df[col] = df[col].str.lower()

# %%
## Ajustes nos datasets ##

# Algumas transformações necessárias
to_time(times, 'Data')
times.Mandante = times.Mandante.replace('athletico-pr','athlético-pr')
times.Visitante = times.Visitante.replace('athletico-pr','athlético-pr')

for i in ['data_inicio', 'data_fim']:
    to_time(temporadas, i)

# colocando para minúsculas (ajuda nas duplicidades)
for i in ['Dia', 'Mandante', 'Visitante','Vencedor', 'Arena','Estado Mandante', 'Estado Visitante', 'Estado Vencedor']:
    to_lower(times, i)

for i in estados.columns:
    to_lower(estados, i)

# renomeando as colunas do dataset
rename_df = {
     'ID': 'id', 
     'Mandante': 'mandante',
     'Chutes': 'chutes', 
     'Chutes a gol': 'chutes_gol', 
     'Posse de bola': 'posse_bola', 
     'Passes': 'passes',
     'Precisão de passe': 'precisao_passes', 
     'Faltas': 'faltas', 
     'Cartões amarelos': 'cartoes_amarelos', 
     'Cartões vermelhos': 'cartoes_vermelhos',
     'Impedimentos': 'impedimentos', 
     'Escanteios': 'escanteios' 
}
df = df.rename(columns = rename_df)

rename_times = {
    'ID': 'id',
    'Rodada': 'rodada',
    'Data': 'data',
    'Horário':'horario',
    'Dia':'dia',
    'Mandante':'mandante',
    'Visitante':'visitante',
    'Vencedor':'vencedor',
    'Arena':'arena',
    'Mandante Placar':'mandante_placar',
    'Visitante Placar':'visitante_placar',
    'Estado Mandante':'estado_mandante',
    'Estado Visitante':'estado_visitante',
    'Estado Vencedor': 'estado_vencedor'
    }
times = times.rename(columns = rename_times)

# retirando o símbolo de % e transformando em float
for i in ['posse_bola','precisao_passes']:
    str_to_float(df, i)
    
# filtrando somente os josgos de 2003 em diante (pontos corridos) --> Temporadas de 2003 a 2020
times = times[(times.data >= '2003-03-29') & (times.data <= '2019-12-08')]

# definindo o perdedor
times['perdedor'] = np.array([0]*times.shape[0])
for i in range(times.shape[0]):
    if times.vencedor.iloc[i] == "-": times.perdedor.iloc[i] = "-"
    elif times.vencedor.iloc[i] == times.mandante.iloc[i]: times.perdedor.iloc[i] = times.visitante.iloc[i]
    elif times.vencedor.iloc[i] == times.visitante.iloc[i]: times.perdedor.iloc[i] = times.mandante.iloc[i]
    else: times.perdedor.iloc[i] = "-"

# turno do jogo
times['turno_dia'] = times.horario
times.loc[(pd.to_datetime(times.horario.str.replace("h",":")) >= '05:00:00'), "turno_dia"] = 'manhã'
times.loc[(pd.to_datetime(times.horario.str.replace("h",":")) >= '12:00:00'), "turno_dia"] = 'tarde'
times.loc[(pd.to_datetime(times.horario.str.replace("h",":")) >= '18:00:00'), "turno_dia"] = 'noite'

# saldo placar --> mandante como referência
times['saldo_placar'] = times.mandante_placar - times.visitante_placar

# pontos ganhos --> mandante como referência
times['pontos_ganhos'] = np.array([0]*times.shape[0])
for i in range(times.shape[0]):
    if times.saldo_placar.iloc[i] > 0: times['pontos_ganhos'].iloc[i] = 3
    elif times.saldo_placar.iloc[i] == 0: times['pontos_ganhos'].iloc[i] = 1
    else: times['pontos_ganhos'].iloc[i] = 0

# Dando nomes aos datasets
df.name = 'df'; times.name = 'times'; estados.name = 'estados'

# %%
# verificando valores faltantes
missing_map(df, 15, 5)
missing_map(times, 15, 5, color="RdPu")

# %%
times_todos = np.unique(
    np.concatenate([times.mandante.unique(), 
                    times.visitante.unique()]))

ufs = np.array(estados.uf)

# %% [markdown]
# #### <font color='red'>Validando os datasets</font>

# %%
# quantidade de partidas por temporada
times.head(3)
# Out:
#         id rodada       data horario      dia      mandante visitante  \
# 1053  1054      1 2003-03-29   16h00   sábado  athlético-pr    grêmio
# 1054  1055      1 2003-03-29   16h00   sábado       guarani     vasco
# 1055  1056      1 2003-03-30   16h00  domingo     fortaleza     bahia
#
#           vencedor             arena  mandante_placar  visitante_placar  \
# 1053  athlético-pr  arena da baixada              2.0               0.0
# 1054       guarani    brinco de ouro              4.0               2.0
# 1055             -          castelão              0.0               0.0
#
#      estado_mandante estado_visitante estado_vencedor perdedor turno_dia  \
# 1053              pr               rs              pr   grêmio     tarde
# 1054              sp               rj              sp    vasco     tarde
# 1055              ce               ba               -        -     tarde
#
#       saldo_placar  pontos_ganhos
# 1053           2.0              3
# ...

# %%
temporadas.head(3)
# Out:
#         temporada      campeao campeao_prim_turno  qtd_clubes data_inicio  \
# 0  temporada_2003     cruzeiro           cruzeiro          24  2003-03-29
# 1  temporada_2004       santos             santos          24  2004-04-21
# 2  temporada_2005  corinthians        corinthians          22  2005-04-11
#
#     data_fim  num_partidas
# 0 2003-12-14           552
# 1 2004-12-19           552
# 2 2005-12-09           462

# %%
df.head(3)
# Out:
#      id  mandante  chutes  chutes_gol  posse_bola  passes  precisao_passes  \
# 0  6041         1    13.0         0.0        45.0   326.0              NaN
# 1  6041         0    16.0         0.0        55.0   388.0              NaN
# 2  6040         1    17.0         0.0        50.0   406.0              NaN
#
#    faltas  cartoes_amarelos  cartoes_vermelhos  impedimentos  escanteios
# 0    20.0               2.0                0.0           3.0         3.0
# 1    21.0               2.0                0.0           0.0         5.0
# 2    20.0               2.0                0.0           2.0        11.0

# %%
## Acescentando uma coluna que representa a temporada que é de cada partida
times['temporada'] = times.data.dt.year
for i in range(times.shape[0]):
    for j in range(temporadas.shape[0]):
        if (times.data.iloc[i] >= temporadas.data_inicio.iloc[j]) and (times.data.iloc[i] <= temporadas.data_fim[j]):
             times['temporada'].iloc[i] =  temporadas.temporada.iloc[j]

# %%
## validando a base com as quantidades de jogos
pd.DataFrame(times.groupby("temporada").id.count()).reset_index().\
    merge(temporadas[["temporada","num_partidas"]], on="temporada", how="inner").style.background_gradient(cmap='RdPu_r')
# Out:
# <style type="text/css">
# #T_3366e_row0_col1, #T_3366e_row0_col2, #T_3366e_row1_col1, #T_3366e_row1_col2 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_3366e_row2_col1 {
#   background-color: #f462a0;
#   color: #f1f1f1;
# }
# #T_3366e_row2_col2 {
#   background-color: #f35f9f;
#   color: #f1f1f1;
# }
# #T_3366e_row3_col1, #T_3366e_row6_col1, #T_3366e_row7_col1, #T_3366e_row8_col1, #T_3366e_row9_col1, #T_3366e_row10_col1, #T_3366e_row11_col1, #T_3366e_row12_col1, #T_3366e_row13_col1, #T_3366e_row14_col1, #T_3366e_row15_col1, #T_3366e_row16_col1 {
#   background-color: #4f006c;
#   color: #f1f1f1;
# }
# #T_3366e_row3_col2, #T_3366e_row4_col2, #T_3366e_row5_col1, #T_3366e_row5_col2, #T_3366e_row6_col2, #T_3366e_row7_col2, #T_3366e_row8_col2, #T_3366e_row9_col2, #T_3366e_row10_col2, #T_3366e_row11_col2, #T_3366e_row12_col2, #T_3366e_row13_col2, #T_3366e_row14_col2, #T_3366e_row15_col2, #T_3366e_row16_col2 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# O que se verificaca que há divergência em 3 temporadas
# - 2007 com 3 jogos a mais
# - 2008 com 3 jogos a menos
# - 2020 faltando 10 jogos

# %% [markdown]
# Quais são esses três jogos doferentes?

# %%
## tem 3 jogos errados em 2007, verificar quais são
times[(np.array(times.data) >= np.array(temporadas.query("temporada == 'temporada_2007'").data_inicio)) & 
      (np.array(times.data) <= np.array(temporadas.query("temporada == 'temporada_2007'").data_fim))].\
    sort_values(by = ['data']).groupby(["mandante"]).mandante.count()
# Out:
# mandante
# américa-rn       19
# athlético-pr     19
# atlético-mg      19
# botafogo-rj      19
# corinthians      19
# cruzeiro         20
# figueirense      19
# flamengo         19
# fluminense       19
# goiás            19
# grêmio           19
# internacional    19
# juventude        19
# náutico          19
# palmeiras        19
# paraná           19
# santos           19
# sport            20
# são paulo        19
# vasco            20
# Name: mandante, dtype: int64

# %% [markdown]
# Vemos que os jogos a mais são:
# - cruzeiro, sport e vasco

# %%
## tem 3 jogos errados em 2007, verificar quais são
times[(np.array(times.data) >= np.array(temporadas.query("temporada == 'temporada_2007'").data_inicio)) & 
      (np.array(times.data) <= np.array(temporadas.query("temporada == 'temporada_2007'").data_fim))].\
    sort_values(by = ['data']).groupby(["visitante"]).visitante.count()
# Out:
# visitante
# américa-rn       19
# athlético-pr     19
# atlético-mg      19
# botafogo-rj      20
# corinthians      19
# cruzeiro         19
# figueirense      19
# flamengo         19
# fluminense       19
# goiás            19
# grêmio           19
# internacional    19
# juventude        19
# náutico          19
# palmeiras        19
# paraná           19
# portuguesa        1
# santos           19
# sport            19
# são paulo        19
# vasco            19
# vitória           1
# Name: visitante, dtype: int64

# %% [markdown]
# Ajuste nos jogos abaixo:
#
# - VITÓRIA não jogou a série A em 2007
# - PORTUGUESA não jogou a série A em 2007

# %%
times[(times.temporada == 'temporada_2007') & 
      ((times.visitante == 'vitória') | (times.visitante == 'portuguesa'))]
# Out:
#         id rodada       data horario     dia mandante   visitante vencedor  \
# 3009  3010      2 2007-05-17   18h10  sábado    sport     vitória        -
# 3011  3012      2 2007-05-17   18h10  sábado    vasco  portuguesa    vasco
#
#                arena  mandante_placar  visitante_placar estado_mandante  \
# 3009  ilha do retiro              0.0               0.0              pe
# 3011    são januário              3.0               1.0              rj
#
#      estado_visitante estado_vencedor    perdedor turno_dia  saldo_placar  \
# 3009               es               -           -     noite           0.0
# 3011               sp              rj  portuguesa     noite           2.0
#
#       pontos_ganhos       temporada
# 3009              1  temporada_2007
# 3011              3  temporada_2007

# %% [markdown]
# Pela lógica, o 3º jogo a ser retirado da temporada de 2007 e colocado na temporada de 2008 é o de <b>cruzeiro x botafogo-rj</b>

# %%
times[(times.temporada == 'temporada_2007') & (times.mandante == 'cruzeiro') & (times.visitante == 'botafogo-rj')]
# Out:
#         id rodada       data horario      dia  mandante    visitante  \
# 3010  3011      2 2007-05-17   18h10   sábado  cruzeiro  botafogo-rj
# 3145  3146     15 2007-07-29   18h10  domingo  cruzeiro  botafogo-rj
#
#       vencedor     arena  mandante_placar  visitante_placar estado_mandante  \
# 3010  cruzeiro  mineirão              1.0               0.0              mg
# 3145  cruzeiro  mineirão              3.0               2.0              mg
#
#      estado_visitante estado_vencedor     perdedor turno_dia  saldo_placar  \
# 3010               rj              mg  botafogo-rj     noite           1.0
# 3145               rj              mg  botafogo-rj     noite           1.0
#
#       pontos_ganhos       temporada
# 3010              3  temporada_2007
# 3145              3  temporada_2007

# %%
times.id.nunique() == times.id.count() ## ou seja, não há valores repetidos para as partidas
# Out:
# True

# %% [markdown]
# Por uma breve pesquisa, percebe-se que os três jogos que pertencem à temporada de 2008 são os jogos com id:
# - 3010, 3011, 3012

# %%
## Ajustando os três jogos a mais de 2007 para 2008
for i in [3010,3011,3012]:
    times.loc[times.id == i, "temporada"] =  'temporada_2008'

# %%
# verificando o ajuste
pd.DataFrame(times.groupby("temporada").id.count()).reset_index().\
    merge(temporadas[["temporada","num_partidas"]], on="temporada", how="inner").style.background_gradient(cmap='mako_r')
# Out:
# <style type="text/css">
# #T_aaac2_row0_col1, #T_aaac2_row0_col2, #T_aaac2_row1_col1, #T_aaac2_row1_col2 {
#   background-color: #0b0405;
#   color: #f1f1f1;
# }
# #T_aaac2_row2_col1, #T_aaac2_row2_col2 {
#   background-color: #3480a4;
#   color: #f1f1f1;
# }
# #T_aaac2_row3_col1, #T_aaac2_row3_col2, #T_aaac2_row4_col1, #T_aaac2_row4_col2, #T_aaac2_row5_col1, #T_aaac2_row5_col2, #T_aaac2_row6_col1, #T_aaac2_row6_col2, #T_aaac2_row7_col1, #T_aaac2_row7_col2, #T_aaac2_row8_col1, #T_aaac2_row8_col2, #T_aaac2_row9_col1, #T_aaac2_row9_col2, #T_aaac2_row10_col1, #T_aaac2_row10_col2, #T_aaac2_row11_col1, #T_aaac2_row11_col2, #T_aaac2_row12_col1, #T_aaac2_row12_col2, #T_aaac2_row13_col1, #T_aaac2_row13_col2, #T_aaac2_row14_col1, #T_aaac2_row14_col2, #T_aaac2_row15_col1, #T_aaac2_row15_col2, #T_aaac2_row16_col1, #T_aaac2_row16_col2 {
#   background-color: #def5e5;
#   color: #000000;
# }
# </style>
# <table id="T_aaac2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# <hr style='border: 1.5px solid LimeGreen;'>

# %%
missing_map(df,color="viridis")

# %%
times[times.id.isin(df.id)].groupby("temporada").id.count()
# Out:
# temporada
# temporada_2015    380
# temporada_2016    379
# temporada_2017    380
# temporada_2018    380
# temporada_2019    380
# Name: id, dtype: int64

# %% [markdown]
# <b>O dataset df só tem dados das temporadas de 2015 a 2019</b>

# %% [markdown]
# Faltam muitas informações deste dataset

# %% [markdown]
# <hr style='border: 1.5px solid orange;'>

# %% [markdown]
# Verificar:
# - Maior vencedor
# - Pior perdedor
# - Pior defesa
# - Melhor defesa
# - Melhor ataque
# - Pior ataque

# %%
# Número de vitórias do time por temporada
times[times.vencedor == "ceará"].groupby("temporada").vencedor.count()
# Out:
# temporada
# temporada_2010    10
# temporada_2011    10
# temporada_2018    10
# temporada_2019    10
# Name: vencedor, dtype: int64

# %% [markdown]
# <hr style='border: 1.5px solid LimeGreen;'>

# %%
# Melhor ataque x Pior ataque

#marcados
gols_marcados = times.groupby("mandante")[['mandante_placar']].sum().reset_index().rename(columns={'mandante':'time'}).merge(
    times.groupby("visitante")[['visitante_placar']].sum().reset_index().rename(columns={'visitante':'time'}), on='time', how='inner')
gols_marcados['gols_marcados'] = gols_marcados['mandante_placar'] + gols_marcados['visitante_placar']
gols_marcados = gols_marcados.rename(columns = {'mandante_placar':'marcou_como_mandante',
                                                'visitante_placar':'marcou_como_visitante'})

#levados
gols_levados = times.groupby("visitante")[['mandante_placar']].sum().reset_index().rename(columns={'visitante':'time'}).merge(
    times.groupby("mandante")[['visitante_placar']].sum().reset_index().rename(columns={'mandante':'time'}), on='time', how='inner')
gols_levados['gols_levados'] = gols_levados['mandante_placar'] + gols_levados['visitante_placar']
gols_levados = gols_levados.rename(columns = {'mandante_placar':'levou_como_visitante',
                                                'visitante_placar':'levou_como_mandante'})

gols = gols_marcados.merge(gols_levados,on='time', how='inner')
gols['saldo_gols'] = gols['gols_marcados'] - gols['gols_levados']

#vitórias e derrotas
vitorias_derrotas = times.groupby("vencedor")[['id']].count().reset_index().rename(columns={'vencedor':'time','id':'num_vitorias'})\
                        .merge(times.groupby("perdedor")[['id']].count().reset_index().rename(columns={'perdedor':'time','id':'num_derrotas'}),
                               on='time', how='outer')

resumo_times = gols.merge(vitorias_derrotas, how='left', on='time')

#empates
empates = times[times.vencedor == '-'].groupby('mandante')[['id']].count().reset_index().rename(columns = {'mandante':'time'})\
                .merge(times[times.vencedor == '-'].groupby('visitante')[['id']].count().reset_index().rename(columns = {'visitante':'time'}), on='time', how='inner')
empates['empates'] = empates.id_x + empates.id_y

resumo_times = resumo_times.merge(empates[['time','empates']], on='time', how='left')

resumo_times.merge(temporadas.groupby("campeao")[['temporada']].count().reset_index().rename(columns={'campeao':'time', 'temporada':'temporadas_vencidas'}),on='time', how='left').fillna(0)
# Out:
#                time  marcou_como_mandante  marcou_como_visitante  \
# 0        américa-mg                  68.0                   36.0
# 1        américa-rn                  12.0                   12.0
# 2      athlético-pr                 537.0                  317.0
# 3       atlético-go                  95.0                   81.0
# 4       atlético-mg                 541.0                  362.0
# 5              avaí                 147.0                   93.0
# 6             bahia                 201.0                  139.0
# 7           barueri                  35.0                   24.0
# 8       botafogo-rj                 464.0                  280.0
# 9       brasiliense                  26.0                   23.0
# 10            ceará                  94.0                   56.0
# 11      chapecoense                 136.0                   98.0
# 12      corinthians                 481.0                  342.0
# ...

# %%
print(">> ESTATÍSTICAS GERAIS:\n\n"\
      "- Maior vencedor de jogos do Brasileirão: {} com {} vitórias!\n"\
      "- Pior vencedor de jogos do Brasileirão: {} com {} vitórias!\n"
      .format(
          pd.DataFrame(times[times.vencedor != "-"].vencedor.value_counts()[:1]).reset_index().values[0][0].title(),
          pd.DataFrame(times[times.vencedor != "-"].vencedor.value_counts()[:1]).reset_index().values[0][1],
          pd.DataFrame(times[times.vencedor != "-"].vencedor.value_counts()[-1:]).reset_index().values[0][0].title(),
          pd.DataFrame(times[times.vencedor != "-"].vencedor.value_counts()[-1:]).reset_index().values[0][1],
))
# Out:
# >> ESTATÍSTICAS GERAIS:
#
# - Maior vencedor de jogos do Brasileirão: São Paulo com 309 vitórias!
# - Pior vencedor de jogos do Brasileirão: América-Rn com 4 vitórias!

# %% [markdown]
# #### Criando uma função para ver as estatísticas

# %%
def stats_team(time_escolhido):

    equipe = times[(times.visitante == time_escolhido) | (times.mandante == time_escolhido)]
    time = equipe.copy()
    """
    Seleção da base para o modelo
    
    time = 1
    demais = 0
    y --> 1 = venceu, 2 = empatou, 0 = perdeu
    """

    for col in ['mandante','vencedor']:
        time[col] = time[col].map({time_escolhido: "1", "-": "2"}).fillna("0")

    # add coluna de saldo placar
    for i in range(time.shape[0]):
        if time.vencedor.iloc[i] == "1": time.saldo_placar.iloc[i] = abs(time.saldo_placar.iloc[i])
        elif time.vencedor.iloc[i] == "2": time.saldo_placar.iloc[i] = 0
        else: time.saldo_placar.iloc[i] = -abs(time.saldo_placar.iloc[i])

    time = time[['id','vencedor','rodada','dia','mandante','turno_dia','saldo_placar']]

    time1 = time[['id','vencedor','rodada','mandante','saldo_placar']]
    time2 = pd.get_dummies(time[['id','dia','turno_dia']])
    time_modelo = pd.merge(time1,time2,how='inner',on='id')
    
    """
    Separação da base para as estatísticas
    dados_time[0] time escolhido
    dados_time[1] número de vitórias
    dados_time[2] percentual de vitórias em relação a quantidade dos jogos
    """
    x = equipe.groupby("vencedor")[['id']].count().reset_index().rename(columns = {'id': 'qtd'})
    x['pct_total'] = x.qtd / equipe.shape[0]
    x = x.sort_values(by=['pct_total'], ascending=False)
    
    dados_time = x[x.vencedor == time_escolhido].values[0] # transformando os valores em uma lista
    
    #display(time_modelo, x)
    
    """ RESULTADOS """
    
    print("Time mais vencedor {}".format(times[times.vencedor != "-"].vencedor.value_counts()[:1]))
    
    print("\n\n>>>   Algumas estatísticas sobre o time {}   <<<\n\n"
        "- Número de vitórias do time nas temporadas: {}\n"\
        "- Percentual de vitórias por temporada: {}%\n\n"\
        "- Número de empates do time nas temporadas: {}\n"\
        "- Percentual de empates por temporada: {}%\n\n"\
        "- Número de derrotas do time nas temporadas: {}\n"\
        "- Percentual de derrotas por temporada: {}%\n\n"\
        "- Temporadas dem que o time ficou na 1º divisão: {}\n"\
        "- De {} temporadas da Série A, participou de {} temporadas. Ou seja, de {}%\n\n"\
        .format(time_escolhido.title(),
                dados_time[1],
                round(dados_time[2]*100, 2),
                x[x.vencedor == "-"].iloc[0][1],
                round(x[x.vencedor == "-"].iloc[0][2]*100, 2),
                x[(x.vencedor != time_escolhido) & (x.vencedor != "-")].qtd.sum(),
                round(x[(x.vencedor != time_escolhido) & (x.vencedor != "-")].pct_total.sum()*100, 2),
                equipe.temporada.unique(),
                len(times.temporada.unique()),
                len(equipe.temporada.unique()),
                round(100*len(equipe.temporada.unique()) / len(times.temporada.unique()), 2)
                
        ))

# %% [markdown]
# #### Looping do resultado

# %%
# estatística sobre o time
print(
    "---*---*---*---*---*---*---*---*---*---*---*---*---*---*---\n                   "
    "AVALIAÇÃO DO SEU TIME!\n---*---*---*---*---*---*---*---*---*---*---*---*---*---*---\n")
time_escolhido = input("\nQual o time que deseja avaliar?\n>> Time: ").lower()
assert time_escolhido in times_todos, f"Coloque um dos times que ja participaram do Brasileirão\n {sorted(times_todos)}"
print("\n............................................................")
stats_team(time_escolhido)                                      

# looping
continuar = input("---*---*---*---*---*---*---*---*---*---*---*---*---*---*---\n\n"
"Deseja ver outro time?\nResposta: ")
assert continuar in ("s","sim","S","Sim","yes","Yes","y","Y"), "Sim ou não!"
while continuar in ("s","sim","S","Sim","yes","Yes","y","Y"):
    time_escolhido = input("\nQual o time que deseja avaliar?\n>> Time: ").lower()
    assert time_escolhido in times_todos, f"Coloque um dos times que já participaram do Brasileirão\n {sorted(times_todos)}"
    print("\n---.---.---.---.---.---.---.---.---.---.---.---.---.---.---")
    stats_team(time_escolhido)
    continuar = input("---*---*---*---*---*---*---*---*---*---*---*---*---*---*---\n\n"
    "Deseja ver outro time?\n\nResposta: ")
    assert continuar in ("s","sim","S","Sim","yes","Yes","y","Y"), "Sim ou não!"
# Out:
# ---*---*---*---*---*---*---*---*---*---*---*---*---*---*---
#                    AVALIAÇÃO DO SEU TIME!
# ---*---*---*---*---*---*---*---*---*---*---*---*---*---*---
# Qual o time que deseja avaliar?
# >> Time:  ceará
# ............................................................
# Time mais vencedor são paulo    309
# Name: vencedor, dtype: int64
#
#
# >>>   Algumas estatísticas sobre o time Ceará   <<<
#
# - Número de vitórias do time nas temporadas: 40
# - Percentual de vitórias por temporada: 26.32%
#
# - Número de empates do time nas temporadas: 49
# - Percentual de empates por temporada: 32.24%
#
# - Número de derrotas do time nas temporadas: 63
# - Percentual de derrotas por temporada: 41.45%
#
# - Temporadas dem que o time ficou na 1º divisão: ['temporada_2010' 'temporada_2011' 'temporada_2018' 'temporada_2019']
# - De 17 temporadas da Série A, participou de 4 temporadas. Ou seja, de 23.53%
# ---*---*---*---*---*---*---*---*---*---*---*---*---*---*---
#
# ...

# %% [markdown]
# <hr style='border: 1.5px solid LimeGreen;'>
