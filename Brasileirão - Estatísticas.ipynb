# %% [markdown]
# ***
# <h1 style="background-color:lightblue;font-family:newtimeroman;text-align:center;border-radius: 0px 50px">
#     <font color=black size=7>
#         Estatísticas - Campeonato Brasileiro
#     </font>
# </h1>
#
# <p>Observação: Em desenvolvimento</p>
#
# ***

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Impotando bases e funções

# %%
from ipynb.fs.full.data_wrangling_functions import classificacao, stats_team, df_times

# %%
classificacao()
# Out:
# ---*---*---*---*---*---*---*---*---*---*---*---*---*---*---
#                    CLASSIFICAÇÃO DOS TIMES!
# ---*---*---*---*---*---*---*---*---*---*---*---*---*---*---
# >>> Gostaria de ver a lista de classificação de alguma temporada ou os dados gerais do seu time?
# >R: s
#
# P: Deseja ver algum clube específico?
# > R:  s
# P: Qual clube?
# > R: ceará
# >>> Classificação do Ceará
# P: Alguma temporada específica?
# > R: s
# P: Qual temporada (ano)?
# > R: 2019
#     Clube  PJ  VIT  E  DER    GP    GC   SG
# 15  Ceará  38   10  9   19  36.0  41.0 -5.0

# %%
stats_team(time_escolhido=['ceará'])
# Out:
# >>>   Algumas estatísticas sobre o time Ceará   <<<
#
# - Número de vitórias do time nas temporadas: 40
# - Percentual de vitórias por temporada: 26.32%
#
# - Número de empates do time nas temporadas: 49
# - Percentual de empates por temporada: 32.24%
#
# - Número de derrotas do time nas temporadas: 63
# - Percentual de derrotas por temporada: 41.45%
#
# - Temporadas dem que o time ficou na 1º divisão: ['temporada_2010' 'temporada_2011' 'temporada_2018' 'temporada_2019']
# - De 17 temporadas da Série A, participou de 4 temporadas. Ou seja, de 23.53%

# %%
df_times()
# Out:
#               Clube  marcou_como_mandante  marcou_como_visitante      GP  \
# 0         são paulo                 577.0                  401.0   978.0
# 1            santos                 618.0                  390.0  1008.0
# 2          cruzeiro                 590.0                  388.0   978.0
# 3          flamengo                 549.0                  367.0   916.0
# 4       corinthians                 481.0                  342.0   823.0
# 5     internacional                 502.0                  330.0   832.0
# 6            grêmio                 543.0                  316.0   859.0
# 7        fluminense                 500.0                  391.0   891.0
# 8       atlético-mg                 541.0                  362.0   903.0
# 9      athlético-pr                 537.0                  317.0   854.0
# 10        palmeiras                 501.0                  337.0   838.0
# 11      botafogo-rj                 464.0                  280.0   744.0
# ...
